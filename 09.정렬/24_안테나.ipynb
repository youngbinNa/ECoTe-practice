# %% [markdown]
# <a href="https://colab.research.google.com/github/youngbinNa/ECoTe-practice/blob/main/09.%EC%A0%95%EB%A0%AC/24_%EC%95%88%ED%85%8C%EB%82%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=4
house=[5,1,7,9]

house.sort()

print(house[(n-1)//2])
# Out:
# 5
