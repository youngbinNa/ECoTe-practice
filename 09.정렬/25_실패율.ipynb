# %% [markdown]
# <a href="https://colab.research.google.com/github/youngbinNa/ECoTe-practice/blob/main/09.%EC%A0%95%EB%A0%AC/25_%EC%8B%A4%ED%8C%A8%EC%9C%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 나동빈 답

# %%
n=5
stages=[2, 1, 2, 6, 2, 4, 3, 3]

def solution(n, stages):
  answer=[]
  user=len(stages)
  
  for i in range(1,n+1):
    count=stages.count(i)
    if user==0:
      temp=0
    else:
      temp=count/user
    answer.append((i,temp))
    user-=count
  answer=sorted(answer, key=lambda x:x[1], reverse=True)
  answer=[i[0] for i in answer]
  return answer

print(solution(n, stages))
# Out:
# [3, 4, 2, 1, 5]

# %% [markdown]
# 내 답

# %%
n=5
stages=[2, 1, 2, 6, 2, 4, 3, 3]
user=len(stages)

clear=[0]*(n+1)
_dict={}
#print(fail)
stages.sort()
for stage in stages:
  if not stage==n+1:
    clear[stage]+=1
print(clear)
for i in range(1,n+1):
  if user==0:
    _dict[i]=0
  else:
    _dict[i]=clear[i]/user
  user-=clear[i]
  print(user,clear)
print(_dict)
sorted_dict= sorted(_dict.items(), key = lambda item: item[1], reverse = True)
result=[]
for i in sorted_dict:
  result.append(i[0])
print(result)
# Out:
# [0, 1, 3, 2, 1, 0]
# 7 [0, 1, 3, 2, 1, 0]
# 4 [0, 1, 3, 2, 1, 0]
# 2 [0, 1, 3, 2, 1, 0]
# 1 [0, 1, 3, 2, 1, 0]
# 1 [0, 1, 3, 2, 1, 0]
# {1: 0.125, 2: 0.42857142857142855, 3: 0.5, 4: 0.5, 5: 0.0}
# [3, 4, 2, 1, 5]
