# %% [markdown]
# <a href="https://colab.research.google.com/github/youngbinNa/ECoTe-practice/blob/main/DFS-BFS/20_%EA%B0%90%EC%8B%9C_%ED%94%BC%ED%95%98%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n=4
graph=[['S', 'S', 'S', 'T'], ['X', 'X', 'X', 'X'], ['X', 'X', 'X', 'X'], ['T', 'T', 'T', 'X']]
#data=[('S', 0, 1), ('T', 0, 4), ('T', 1, 0), ('S', 1, 2), ('T', 3, 1), ('T', 4, 2)]
data=[(0, 3), (3, 0), (3, 1), (3, 2)]
result=1e9
find=False
'''
for i in range(n):
  graph.append(list(map(str,input().split())))
  for j in range(n):
    if graph[i][j]=='S':
      data.append(('S',i,j))
    elif graph[i][j]=='T':
      data.append(('T',i,j))
print(graph)
print(data)
'''
#from collections import deque

        
'''        
def check():
  steps=[(-1,0),(1,0),(0,-1),(0,1)] # 상하좌우
  count=0
  for student in data_student:
    x,y=student
    for step in steps:
      nx=x+step[0]
      ny=y+step[1]
      if count>0:
        return False
      if 0<=nx<n and 0<=ny<n:
        if temp[nx][ny]=='T':
          count+=1
        elif temp[nx][ny]=='X':
          spread(nx,ny)
  return True
'''      
def check_score(x,y):
  steps=[(-1,0),(1,0),(0,-1),(0,1)] # 상하좌우
  #result=0
  for step in steps:
    nx=x+step[0]
    ny=y+step[1]
    if 0<=nx<n and 0<=ny<n:
      if graph[nx][ny]=='X':
        graph[nx][ny]='U'
        check_score(nx,ny)
        graph[nx][ny]='X'
      elif graph[nx][ny]=='S':
        print(graph,nx,ny)
        return True
  
  return False
'''      
def dfs(count):
  global result
  if count == 3:
        for i in range(n):
            for j in range(n):
                if graph[i][j] == 'T':
                    check_score(i, j)
        # 안전 영역의 최대값 계산
        if check():
          return 'YES'
        else:
          return 'NO'
        return
  for i in range(n):
        for j in range(n):
            if graph[i][j] == 'X':
                graph[i][j] = 'O'
                count += 1
                dfs(count)
                graph[i][j] = 'X'
                count -= 1
'''
def dfs(count):
  global result,find
  if count == 3:
    #print(graph)
    for teacher in data:
      i,j=teacher
      if not check_score(i, j):
        find=True
        break
      #else: return 'NO'
      #print(check_score(i, j))
      #result = min(result, check_score(i,j))
      #print(result)
    #return
  for i in range(n):
    for j in range(n):
        if graph[i][j] == 'X':
            graph[i][j] = 'O'
            count += 1
            dfs(count)
            graph[i][j] = 'X'
            count -= 1
dfs(0)
print(find)
# Out:
# [['S', 'S', 'S', 'T'], ['O', 'O', 'O', 'X'], ['X', 'X', 'X', 'X'], ['T', 'T', 'T', 'X']] 0 2
# [['S', 'S', 'S', 'T'], ['O', 'O', 'X', 'O'], ['X', 'X', 'X', 'X'], ['T', 'T', 'T', 'X']] 0 2
# [['S', 'S', 'S', 'T'], ['O', 'O', 'U', 'O'], ['U', 'U', 'U', 'X'], ['T', 'T', 'T', 'X']] 0 2
# [['S', 'S', 'S', 'T'], ['O', 'O', 'U', 'U'], ['O', 'X', 'U', 'U'], ['T', 'T', 'T', 'X']] 0 2
# [['S', 'S', 'S', 'T'], ['O', 'O', 'U', 'U'], ['O', 'X', 'X', 'X'], ['T', 'T', 'T', 'X']] 0 2
# [['S', 'S', 'S', 'T'], ['O', 'O', 'X', 'X'], ['O', 'X', 'X', 'X'], ['T', 'T', 'T', 'X']] 0 2
# [['S', 'S', 'S', 'T'], ['O', 'O', 'U', 'U'], ['X', 'O', 'U', 'U'], ['T', 'T', 'T', 'X']] 0 2
# [['S', 'S', 'S', 'T'], ['O', 'O', 'U', 'U'], ['X', 'O', 'X', 'X'], ['T', 'T', 'T', 'X']] 0 2
# [['S', 'S', 'S', 'T'], ['O', 'O', 'X', 'X'], ['X', 'O', 'X', 'X'], ['T', 'T', 'T', 'X']] 0 2
# [['S', 'S', 'S', 'T'], ['O', 'O', 'U', 'U'], ['X', 'X', 'O', 'X'], ['T', 'T', 'T', 'X']] 0 2
# ...
